# %% [markdown]
# ## Quantum Feature Selection with using NEC Annealing Machine - by QFriends Team

# %%
import pandas as pd
import numpy as np
from plots import plot_weather_signals
import matplotlib.pyplot as plt
from copy import deepcopy
from plots import plot_two_var_model 
import itertools
from qbraid.runtime import QbraidProvider 
from scipy.optimize import curve_fit

# %% [markdown]
# ## Open and Clean Weather Data
# The data has no missing label or out of range values. Skipping clean stage

# %%
df = pd.read_csv('weather-010824-061024.csv')
df.head()

dfw_clean = df.dropna()
dfw_clean = dfw_clean.fillna(0)
print("Shape after cleaning:", dfw_clean.shape)
df = dfw_clean
df.describe()
# Out:
# Shape after cleaning: (1658, 12)
#                  id          hum         pres      rain_1h   wind_speed  \
# count   1658.000000  1658.000000  1658.000000  1658.000000  1658.000000
# mean   42580.500000    63.146562  1013.204463     0.027835     3.855072
# std      478.767689    12.288755     3.075757     0.275233     2.109445
# min    41752.000000    16.000000  1002.000000     0.000000     0.140000
# 25%    42166.250000    55.000000  1011.000000     0.000000     2.240000
# 50%    42580.500000    65.000000  1013.000000     0.000000     3.600000
# 75%    42994.750000    72.000000  1015.000000     0.000000     5.140000
# max    43409.000000    89.000000  1024.000000     6.300000    12.860000
#
#           wind_deg   clouds_all     max_temp     min_temp     ave_temp  \
# count  1658.000000  1658.000000  1658.000000  1658.000000  1658.000000
# mean    223.652593    12.585042    25.521043    24.121049    24.915084
# std     118.143934    21.160828     4.465253     4.554314     4.424531
# min       0.000000     0.000000    13.750000    11.810000    12.850000
# 25%     150.000000     0.000000    22.660000    20.970000    22.010000
# 50%     210.000000     0.000000    25.440000    23.935000    24.970000
# 75%     340.000000    20.000000    28.810000    27.680000    28.300000
# max     360.000000   100.000000    38.810000    35.810000    38.770000
#
#        cod_weather
# count  1658.000000
# mean    791.086852
# std      61.331334
# min     200.000000
# 25%     800.000000
# 50%     800.000000
# 75%     801.000000
# max     804.000000

# %% [markdown]
# ## Ready the weather data
# Remove unnesary id and time stamp data

# %%
features = list(df.columns)
features.remove('id')
features.remove('ts_get')
features.remove('min_temp')
features.remove('max_temp')

# Using 'cod_weather' as classification data.
features.remove('cod_weather')
data_points = len(df['hum'])

format_data = list()
for feature in features:
    format_data.append(np.array(df[feature]).reshape(data_points, 1))

# %% [markdown]
# ## Classify the weather data
# <p> Lightning = 0
# <p> Rain      = 1
# <p> Sunny     = 2

# %%
cod_weather = np.zeros(data_points).reshape(data_points, 1)

for i in range(len(df['cod_weather'])):
    # Lightning
    if 0 <= df['cod_weather'][i] < 300 :
        cod_weather[i] = 0
    # Rain
    elif 300 <= df['cod_weather'][i] < 500:
        cod_weather[i] = 1
    elif 500 <= df['cod_weather'][i] < 800:
        cod_weather[i] = 2
    # Sunny
    else:
        cod_weather[i] = 1

# %%
format_data_with_class = deepcopy(format_data)
format_data_with_class.append(cod_weather)
feature_with_data = deepcopy(features)
feature_with_data.append('cod_weather')

# %% [markdown]
# ## Weather System Input and Outputs

# %%
weather_problem = pd.DataFrame(np.hstack(format_data_with_class), columns=feature_with_data)
plot_weather_signals(weather_problem)

# %% [markdown]
# ## The two_var_model function in the next cell defines a linear model of two variables.

# %%
def two_var_model(in_tuple, a, b):
    ina, inb = in_tuple
    return a*ina + b*inb

# %% [markdown]
# ## Use the SciPy library's curve_fit function to try to predict the variable of interest from two of three features. The model with less-correlated features performs better.

# %%
model = []
two_vars = []
toy = weather_problem
for f0, f1 in itertools.combinations(features, 2):  
    two_vars.append((f0, f1))
    popt, pcov = curve_fit(two_var_model, (toy[f0].values, toy[f1].values), toy['cod_weather'].values)
    model.append(two_var_model((toy[f0].values, toy[f1].values), popt[0], popt[1]).reshape(len(toy), 1))
    print("Standard deviation for selection of features {} and {} is {:.4f}.".format(f0, f1, max(np.sqrt(np.diag(pcov)))))
model_df = pd.DataFrame(np.hstack(model), columns=two_vars)

plot_two_var_model(model_df, toy)
# Out:
# Standard deviation for selection of features hum and pres is 0.0003.
# Standard deviation for selection of features hum and rain_1h is 0.0208.
# Standard deviation for selection of features hum and wind_speed is 0.0020.
# Standard deviation for selection of features hum and wind_deg is 0.0002.
# Standard deviation for selection of features hum and clouds_all is 0.0003.
# Standard deviation for selection of features hum and ave_temp is 0.0006.
# Standard deviation for selection of features pres and rain_1h is 0.0128.
# Standard deviation for selection of features pres and wind_speed is 0.0018.
# Standard deviation for selection of features pres and wind_deg is 0.0000.
# Standard deviation for selection of features pres and clouds_all is 0.0002.
# Standard deviation for selection of features pres and ave_temp is 0.0009.
# Standard deviation for selection of features rain_1h and wind_speed is 0.0447.
# Standard deviation for selection of features rain_1h and wind_deg is 0.0438.
# Standard deviation for selection of features rain_1h and clouds_all is 0.0789.
# Standard deviation for selection of features rain_1h and ave_temp is 0.0202.
# Standard deviation for selection of features wind_speed and wind_deg is 0.0039.
# Standard deviation for selection of features wind_speed and clouds_all is 0.0030.
# Standard deviation for selection of features wind_speed and ave_temp is 0.0029.
# Standard deviation for selection of features wind_deg and clouds_all is 0.0005.
# Standard deviation for selection of features wind_deg and ave_temp is 0.0004.
# Standard deviation for selection of features clouds_all and ave_temp is 0.0003.

# %% [markdown]
# ## Quantifying Information: Shannon Entropy

# %%
def prob(dataset, max_bins=10):
    num_rows, num_columns = dataset.shape
    bins = [min(len(np.unique(dataset[:, ci])), max_bins) for ci in range(num_columns)]

    freq, _ = np.histogramdd(dataset, bins)
    p = freq / np.sum(freq)
    return p

def shannon_entropy(p):
    p = p.flatten()
    return -sum(pi*np.log2(pi) for pi in p if pi)

# %%
from plots import plot_se 

max_bins = 10

x_uniform = np.random.uniform(0, 1, (1000, 1))
x_exp = np.exp(-np.linspace(0, 10, 1000)/2).reshape(1000, 1)
x_vals = np.random.choice([0, 1],(1000, 1), p=[0.1, 0.9])

data = list()
for bins in range(1, max_bins):
    uniform_se = shannon_entropy(prob(x_uniform, bins))
    exp_se = shannon_entropy(prob(x_exp, bins))
    vals_se = shannon_entropy(prob(x_vals, bins))                               
    data.append({'Bins': bins, 'Uniform': uniform_se, 'Maximum': np.log2(bins), 'Exp': exp_se, 'Vals': vals_se})

# %% [markdown]
# ## Conditional Shannon Entropy

# %%
def conditional_shannon_entropy(p, *conditional_indices):
    axis = tuple(i for i in np.arange(len(p.shape)) if i not in conditional_indices)
    return shannon_entropy(p) - shannon_entropy(np.sum(p, axis=axis))

# %%
def mutual_information(p, j):
    return shannon_entropy(np.sum(p, axis=j)) - conditional_shannon_entropy(p, j)

# %% [markdown]
# ## Mutual Information on the Weather Problem

# %%
from plots import plot_mi 
mi = {}
for column in toy.columns:
    if column == 'cod_weather':
        continue
    mi[column] = mutual_information(prob(toy[['cod_weather', column]].values), 1)

plot_mi(mi)

# %%
from scipy.stats import linregress
from plots import plot_lingress 

model = []
var_rval = []
for column in toy.columns:
    if column == 'out':
        continue
    slope, intercept, rvalue, pvalue, stderr = linregress(toy[column].values, toy['cod_weather'].values)  
    model.append((slope*toy[column].values + intercept).reshape(len(toy), 1))
    var_rval.append((column, rvalue))

plot_lingress(pd.DataFrame(np.hstack(model), columns=var_rval), toy)

# %% [markdown]
# ## Conditional Mutual Information

# %%
def conditional_mutual_information(p, j, *conditional_indices):
    marginal_conditional_indices = [i-1 if i > j else i for i in conditional_indices]

    return (conditional_shannon_entropy(np.sum(p, axis=j), *marginal_conditional_indices)
            - conditional_shannon_entropy(p, j, *conditional_indices))

# %% [markdown]
# ## Solving Feature Selection on a Quantum Computer

# %%
import dimod
bqm = dimod.BinaryQuadraticModel.empty(dimod.BINARY)

for column in toy.columns:
    if column == 'cod_weather':
        continue
    mi = mutual_information(prob(toy[['cod_weather', column]].values), 1)
    bqm.add_variable(column, -mi)

for item in bqm.linear.items():
    print("{}: {:.3f}".format(item[0], item[1]))
# Out:
# hum: -0.017
# pres: -0.017
# rain_1h: -0.057
# wind_speed: -0.009
# wind_deg: -0.012
# clouds_all: -0.035
# ave_temp: -0.006

# %%
for f0, f1 in itertools.combinations(features, 2):
    cmi_01 = conditional_mutual_information(prob(toy[['cod_weather', f0, f1]].values), 1, 2)
    cmi_10 = conditional_mutual_information(prob(toy[['cod_weather', f1, f0]].values), 1, 2)
    bqm.add_interaction(f0, f1, -cmi_01)
    bqm.add_interaction(f1, f0, -cmi_10)

bqm.normalize() 

for item in bqm.quadratic.items():
    print("{}: {:.3f}".format(item[0], item[1]))
# Out:
# ('pres', 'hum'): -0.833
# ('rain_1h', 'hum'): -0.841
# ('rain_1h', 'pres'): -0.682
# ('wind_speed', 'hum'): -0.671
# ('wind_speed', 'pres'): -0.724
# ('wind_speed', 'rain_1h'): -0.878
# ('wind_deg', 'hum'): -0.914
# ('wind_deg', 'pres'): -0.931
# ('wind_deg', 'rain_1h'): -0.788
# ('wind_deg', 'wind_speed'): -1.000
# ('clouds_all', 'hum'): -0.843
# ('clouds_all', 'pres'): -0.803
# ('clouds_all', 'rain_1h'): -0.947
# ('clouds_all', 'wind_speed'): -0.823
# ('clouds_all', 'wind_deg'): -0.914
# ('ave_temp', 'hum'): -0.613
# ('ave_temp', 'pres'): -0.774
# ('ave_temp', 'rain_1h'): -0.735
# ('ave_temp', 'wind_speed'): -0.608
# ('ave_temp', 'wind_deg'): -0.856
# ('ave_temp', 'clouds_all'): -0.947

# %%
from plots import plot_solutions 
sampler = dimod.ExactSolver()
result = sampler.sample(bqm)
plot_solutions(result)

# %%
k = 2
bqm.update(dimod.generators.combinations(bqm.variables, k, strength=4))
result = sampler.sample(bqm)
plot_solutions(result)

# %%
print(result.lowest())
# Out:
#   ave_temp clouds_all hum pres rain_1h wind_deg wind_speed    energy num_oc.
# 0        0          1   0    0       1        0          0 -2.005001       1
# ['BINARY', 1 rows, 1 samples, 7 variables]

# %%
ising = bqm.to_ising()
ising
# Out:
# ({'hum': 4.723730826319722,
#   'pres': 4.71436685430205,
#   'rain_1h': 4.452930215807353,
#   'wind_speed': 4.774350142466431,
#   'wind_deg': 4.580239480737171,
#   'clouds_all': 4.480891823875646,
#   'ave_temp': 4.833983270566722},
#  {('pres', 'hum'): 1.7918090605913493,
#   ('rain_1h', 'hum'): 1.7897135764409482,
#   ('rain_1h', 'pres'): 1.8293917140998328,
#   ('wind_speed', 'hum'): 1.8323327891313252,
#   ('wind_speed', 'pres'): 1.8190240737454477,
#   ('wind_speed', 'rain_1h'): 1.7804476253922907,
#   ('wind_deg', 'hum'): 1.771570609598265,
#   ('wind_deg', 'pres'): 1.7672733128698639,
#   ('wind_deg', 'rain_1h'): 1.8031051034100827,
#   ('wind_deg', 'wind_speed'): 1.75,
#   ('clouds_all', 'hum'): 1.7893256402541189,
#   ('clouds_all', 'pres'): 1.7992928317951076,
#   ('clouds_all', 'rain_1h'): 1.7632627335204878,
#   ('clouds_all', 'wind_speed'): 1.794251737046861,
#   ('clouds_all', 'wind_deg'): 1.7714170118719101,
#   ('ave_temp', 'hum'): 1.8468295252590587,
#   ('ave_temp', 'pres'): 1.8064788833976317,
#   ('ave_temp', 'rain_1h'): 1.816186421065094,
#   ('ave_temp', 'wind_speed'): 1.8479803288123966,
#   ('ave_temp', 'wind_deg'): 1.7860321070327423,
#   ('ave_temp', 'clouds_all'): 1.763191012463068},
#  10.841576516277215)

# %% [markdown]
# # Using NEC Machine

# %%
provider=QbraidProvider()
device = provider.get_device("nec_vector_annealer")
device.status()
# Out:
# <DeviceStatus.ONLINE: 'online'>

# %%
target_spec=device.profile.get("program_spec")
target_spec
# Out:
# <ProgramSpec('cpp_pyqubo.Model', 'cpp_pyqubo')>

# %%
from pyqubo import Spin 
from qbraid import QbraidProvider
s1, s2, s3, s4, s5, s6, s7, s8, s9 = Spin("s1"), Spin("s2"),Spin("s3"),Spin("s4"),Spin("s5"),Spin("s6"),Spin("s7"),Spin("s8"),Spin("s9")

# %%
H = (8.347123739903852*s1+8.307557424808742*s2
+8.721443359049427*s3
+8.469893763858273*s4 + 8.084405500394826*s5+ 8.18025382553962*s6
+8.06237980541793*s7 + 8.692846409926123*s8 + 8.72002856314697*s9+1.7918090605913493*s1*s2+1.8468295252590587*s1*s3+1.8064788833976344*s2*s3+1.8323327891313252*s1*s4+ 1.8190240737454477*s2*s4+1.8479803288123966*s3*s4+ 1.7897135764409482*s1*s5+ 1.8293917140998328*s2*s5+1.816186421065094*s3*s5+ 1.7804476253922907*s4*s5+1.771570609598265*s1*s6
+1.7672733128698639*s2*s6+1.7860321070327423*s3*s6
+1.75*s4*s6+1.8031051034100827*s5*s6+1.7893256402541189*s1*s7
+1.7992928317951076*s2*s7+1.763191012463068*s3*s7+1.794251737046861*s4*s7+1.7632627335204878*s5*s7+ 1.7714170118719101*s6*s7+ 1.7876318137831895*s1*s8
+1.799793483483567*s2*s8+ 1.9380103524080659*s3*s8
+1.8573562909146333*s4*s8+ 1.8242001258450942*s5*s8+ 1.80398508937607*s6*s8+ 1.778772337021622*s7*s8+ 1.8357610998009404*s1*s9 + 1.7933970870231235*s2*s9+ 1.949449736074638*s3*s9+ 1.8381873304772125*s4*s9+ 1.8072751587423803*s5*s9
+1.79602925542638*s6*s9+1.802715644520664*s7*s9+1.9479189008158353*s8*s9
+26.30653258853448)

# %%
model=H.compile()
qubo, offset=model.to_qubo()

# %%
provider=QbraidProvider()
device = provider.get_device("nec_vector_annealer")

# %%
params={
"offset":offset,
"num_reads":10, 
}
job=device.run(model, params=params)
result=job.result()
print(result.data.to_dict())
# Out:
# {'solutions': [{'spin': {'s1': 0, 's2': 0, 's3': 0, 's4': 0, 's5': 1, 's6': 0, 's7': 1, 's8': 0, 's9': 0}, 'energy': -2.0050012683126255, 'time': 0.0059809996746480465, 'constraint': True, 'memory_usage': 1.189453125}], 'num_solutions': 1}

# %% [markdown]
# ## Results

# %% [markdown]
# <b> Correlation: </b>
# <p> s5 --> Clouds_all
# <p> s7 --> Rain_1h
